# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import ndimage as ndi

from skimage import feature, filters, color


# Generate noisy image of a square
im = np.zeros((128, 128))
im[32:-32, 32:-32] = 1

im = ndi.rotate(im, 15, mode='constant')
im = ndi.gaussian_filter(im, 4)
im += 0.2 * np.random.random(im.shape)
print(im)
# Compute the Canny filter for two values of sigma
edges1 = feature.canny(im)
edges2 = feature.canny(im, sigma=3)

# display results
fig, (ax1, ax2, ax3) = plt.subplots(nrows=1, ncols=3, figsize=(8, 3),
                                    sharex=True, sharey=True)

ax1.imshow(im, cmap=plt.cm.gray)
ax1.axis('off')
ax1.set_title('noisy image', fontsize=20)

ax2.imshow(edges1, cmap=plt.cm.gray)
ax2.axis('off')
ax2.set_title(r'Canny filter, $\sigma=1$', fontsize=20)

ax3.imshow(edges2, cmap=plt.cm.gray)
ax3.axis('off')
ax3.set_title(r'Canny filter, $\sigma=3$', fontsize=20)

fig.tight_layout()

plt.show()
# Out:
# [[0.1472071  0.08433902 0.07940914 ... 0.05647617 0.18556555 0.09907734]
#  [0.13520819 0.11117938 0.10817883 ... 0.11078884 0.14198351 0.10804043]
#  [0.10258508 0.13017759 0.15434195 ... 0.17374323 0.05790201 0.15726731]
#  ...
#  [0.07594187 0.05731133 0.10736687 ... 0.03448682 0.06991373 0.04650388]
#  [0.14891253 0.13197825 0.05410097 ... 0.00459959 0.08869732 0.10435091]
#  [0.09195934 0.16697943 0.18922329 ... 0.01827902 0.16840928 0.0289118 ]]

# %%
from keras.preprocessing import image
img_path = 'pics/front/Jan_22_hamburg_colors_day/val_data/phone/red_day00031.png'

img = image.load_img(img_path, target_size=(128, 128), color_mode='grayscale')
im = (image.img_to_array(img))
im /= 255.

print(im.shape)

im = im.reshape(128, 128)
#print(im.shape)
plt.imshow(im)
plt.show()


#img = filters.scharr(im)

#plt.imshow(img)
#plt.show()

img = filters.sobel(im)

plt.imshow(img)
plt.show()

img = feature.canny(im, sigma=1)

plt.imshow(img)
plt.show()

#img = filters.laplace(im)

#plt.imshow(img)
#plt.show()

#img = filters.hessian(im)

#plt.imshow(img)
#plt.show()

#img = filters.hessian(im)

#plt.imshow(img)
#plt.show()

#img, none = filters.gabor(im, frequency=0.6)

#plt.imshow(img)
#plt.show()


img = filters.farid(im)

plt.imshow(img)
plt.show()

#im = color.rgb2gray(im)
#plt.imshow(im)
#plt.show()
# Out:
# (128, 128, 1)

# %%
import matplotlib.pyplot as plt
import keras.preprocessing.image as kimg

from keras.preprocessing import image
from skimage import feature, filters, color

from skimage import data, color, io
from skimage.transform import rescale, resize, downscale_local_mean

import os
Dir = "pics/OneSortOfClothes/OneSort/DayNightSobel/val_data/"


path, dirs, files = next(os.walk(Dir, topdown=True))
print("Pictures: ",  len(files))
print(dirs)
# Out:
# Pictures:  0
# ['noperson', 'crooked', 'straight', 'drinking', 'phone']

# %%
for d in dirs:
    path, dirs, files = next(os.walk(Dir + d, topdown=True))
    for i in files:
        img = image.load_img(Dir + d + "/" + i, target_size=(128, 128), color_mode='grayscale')
        im = (image.img_to_array(img))
        im /= 255.
        im = im.reshape(128, 128)
        image_filtered = filters.sobel(im)
        io.imsave(Dir + d + "/"  + i, image_filtered)
        #plt.imshow(image_resize, cmap='gray') 
        #print(i)
# Out:
# <ipython-input-4-dd10cec36761>:9: UserWarning: Ausarbeitung/pics/OneSortOfClothes/OneSort/DayNightSobel/val_data/noperson/00040.png is a low contrast image
#   io.imsave(Dir + d + "/"  + i, image_filtered)
# <ipython-input-4-dd10cec36761>:9: UserWarning: Ausarbeitung/pics/OneSortOfClothes/OneSort/DayNightSobel/val_data/noperson/00069.png is a low contrast image
#   io.imsave(Dir + d + "/"  + i, image_filtered)
# <ipython-input-4-dd10cec36761>:9: UserWarning: Ausarbeitung/pics/OneSortOfClothes/OneSort/DayNightSobel/val_data/noperson/00020.png is a low contrast image
#   io.imsave(Dir + d + "/"  + i, image_filtered)
# <ipython-input-4-dd10cec36761>:9: UserWarning: Ausarbeitung/pics/OneSortOfClothes/OneSort/DayNightSobel/val_data/noperson/00072.png is a low contrast image
#   io.imsave(Dir + d + "/"  + i, image_filtered)
# <ipython-input-4-dd10cec36761>:9: UserWarning: Ausarbeitung/pics/OneSortOfClothes/OneSort/DayNightSobel/val_data/noperson/00075 (copy).png is a low contrast image
# ...
